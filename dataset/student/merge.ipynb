# %%
import pandas as pd

# %%
df_port = pd.read_csv('student-por.csv', sep=';')
df_mat = pd.read_csv('student-mat.csv', sep=';')

# %%
df_mat.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
df_port.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Merge datasets

# %%
merge_dataset = pd.concat([df_port, df_mat], axis=0)

# %%
merge_dataset.reset_index(drop=True, inplace=True)

# %%
merge_dataset.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
merge_dataset.tail()
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1039     MS   M   20       U     LE3       A     2     2  services  services
# 1040     MS   M   17       U     LE3       T     3     1  services  services
# 1041     MS   M   21       R     GT3       T     1     1     other     other
# 1042     MS   M   18       R     LE3       T     3     2  services     other
# 1043     MS   M   19       U     LE3       T     1     1     other   at_home
#
#       ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 1039  ...      5        5      4     4     5      4       11   9   9   9
# 1040  ...      2        4      5     3     4      2        3  14  16  16
# 1041  ...      5        5      3     3     3      3        3  10   8   7
# 1042  ...      4        4      1     3     4      5        0  11  12  10
# 1043  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
df_port.shape
# Out:
# (649, 33)

# %%
df_mat.shape
# Out:
# (395, 33)

# %%
merge_dataset.shape
# Out:
# (1044, 33)

# %% [markdown]
# ### Save dataset

# %%
merge_dataset.to_csv('merged.csv', index=False)

# %% [markdown]
# # Done
